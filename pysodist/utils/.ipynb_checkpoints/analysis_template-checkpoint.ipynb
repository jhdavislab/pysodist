# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pysodist.commands.plot_spectra as ps
import matplotlib
matplotlib.use('nbAgg')
import matplotlib.pyplot as plt

# %% [markdown]
# ## Setup
# * Here we will set all of the relevant paths pointing to your isodist output

# %%
wd = '/cold2/jhdavis/pysodist_rewrite/Ace_15N_600_DIA/' #this is your working directory for the sample you're analyzing
ft = '/cold2/jhdavis/pysodist_rewrite/Ace_15N_600_DIA/model_15Npulse_3peaks_isodist_fits/' #this is where your isodist fits are stored
ip = '/cold2/jhdavis/pysodist_rewrite/Ace_15N_600_DIA/model_15Npulse_3peaks_final_plots/interactive_plots/' #where you would like to store any interactive plots
isodist_result = '/cold2/jhdavis/pysodist_rewrite/Ace_15N_600_DIA/model_15Npulse_3peaks_isodist_outputs/model_15Npulse_3peaks_output.csv' # your isodist result file
NUM = ['AMP_U'] #set these fields to the ratio you'd like to inspect.
DEN = ['AMP_U', 'AMP_F']
id_result = ps.parse_isodist_csv(isodist_result)

#####################################################################
id_result = ps.set_current_ratio(id_result, numerator = NUM, denominator = DEN) #always run set_current_ratio before plotting!
ratio_string = '['+'+'.join([num for num in NUM])+']/['+'+'.join([den for den in DEN])+']' #always run update ratio_string before plotting!
######################################################################

# %% [markdown]
# ## Plot dataset distributions

# %%
#info for the stat plotting function
ps.plot_csv_stats?

# %%
stats_fig = ps.plot_csv_stats(id_result, ratio_string, output_path=None, png=True, histo_fields=['chisq', 'B', 'OFF', 'GW', 'current_ratio', 'AMP_F'])
# Out:
# <img src="data:image/png;base64,..." width="720">

# %% [markdown]
# ### Choose whether you would like to use interactive filtering.
# * This requires that qgrid is installed in your conda enviornment

# %%
__INTERACTIVE__ = True #Set this to True if you would like to use the GUI-based interactive filtering tools
if __INTERACTIVE__:
    import qgrid
    qg = qgrid.show_grid(id_result, show_toolbar=True)

# %% [markdown]
# ### Interactive filtering
# * use the filter buttons on each column to choose cuttoffs
# * eventually select the rows you want by clicking them (use 'shift' and 'ctrl' to select multiple rows)

# %%
qg # Only run this cell if you are using interactive filtering
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
filt_id = qg.get_selected_df() #saves the selected rows
filt_id
# Out:
#                                                  file     protein  \
# 1   ./spectra/YAGEVSHDDKHIIVDGK_3_628.315_53-69_30...  G3P3_YEAST
# 2   ./spectra/YAGEVSHDDKHIIVDGK_3_628.315_53-69_30...  G3P3_YEAST
# 3   ./spectra/YAGEVSHDDKHIIVDGK_3_628.315_53-69_30.23  G3P3_YEAST
# 4   ./spectra/YAGEVSHDDKHIIVDGK_3_628.315_53-69_30...  G3P3_YEAST
# 5   ./spectra/YAGEVSHDDKHIIVDGK_3_628.315_53-69_30...  G3P3_YEAST
# 6   ./spectra/YAGEVSHDDKHIIVDGK_3_628.315_53-69_30...  G3P3_YEAST
# 7   ./spectra/YAGEVSHDDKHIIVDGK_3_628.315_53-69_30...  G3P3_YEAST
# 8   ./spectra/YAGEVSHDDKHIIVDGK_3_628.315_53-69_30...  G3P3_YEAST
# 9   ./spectra/YAGEVSHDDKHIIVDGK_3_628.315_53-69_30...  G3P3_YEAST
# 10  ./spectra/YAGEVSHDDKHIIVDGK_3_628.315_53-69_30...  G3P3_YEAST
# 11  ./spectra/YAGEVSHDDKHIIVDGK_3_628.315_53-69_30...  G3P3_YEAST
# 12  ./spectra/YAGEVSHDDKHIIVDGK_3_628.315_53-69_30...  G3P3_YEAST
# 13  ./spectra/YAGEVSHDDKHIIVDGK_3_628.315_53-69_30...  G3P3_YEAST
# ...

# %%
filt_stats_fig = ps.plot_csv_stats(filt_id, ratio_string, output_path=None, png=True, histo_fields=['chisq', 'B', 'OFF', 'GW', 'current_ratio', 'AMP_F'])
# Out:
# <img src="data:image/png;base64,..." width="720">

# %% [markdown]
# ### Programmatic filtering
# * A couple examples are shown - modify as you see fit

# %%
filt_id = id_result[(id_result['OFF']<0.05) & (id_result['OFF']>=-0.025)] #boolean filtering
print('filtering resulted in saving ' + str(filt_id.shape[0]) + ' fits from an original ' + str(id_result.shape[0]) + ' fits.')
# Out:
# filtering resulted in saving 201 fits from an original 206 fits.

# %%
filt_stats_fig = ps.plot_csv_stats(filt_id, ratio_string, output_path=None, png=True, histo_fields=['chisq', 'B', 'OFF', 'GW', 'current_ratio', 'AMP_F'])
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
all_proteins = list(set(filt_id['protein'].values))
proteins_of_interest = all_proteins[0:2]
filt_id = filt_id[filt_id['protein'].str.contains('|'.join(proteins_of_interest))]
print('selected proteins: ' + str(list(set(filt_id['protein']))))
# Out:
# selected proteins: ['G3P3_YEAST', 'KPYK1_YEAST']

# %%
filt_stats_fig = ps.plot_csv_stats(filt_id, ratio_string, output_path=None, png=True, histo_fields=['chisq', 'B', 'OFF', 'GW', 'current_ratio', 'AMP_F'])
# Out:
# <img src="data:image/png;base64,..." width="720">

# %% [markdown]
# ## Plot data in a protein-centric manner
# * Use these cells to look at data on a protein-by-protein basis

# %%
ps.plot_all_ratios?

# %%
ps.plot_all_ratios(id_result, numerator=NUM, denominator=DEN, saved_output_path=None, png=False, pdf=False, protein_list=proteins_of_interest)
# Out:
# plotting abundance for protein: G3P3_YEAST
# <img src="data:image/png;base64,..." width="192">
# plotting abundance for protein: KPYK1_YEAST
# <img src="data:image/png;base64,..." width="384">

# %%
ADH1_peptides = ps.get_by_protein(id_result, 'ADH1_YEAST') #this gets the related spectra by protein name.
#note that you could get related spectra by direct selection with pandas selectors.

# %%
#plot_ratios functions using a set of related spectra rows obtained from above.
ps.plot_ratios?

# %%
ADH1_plots = ps.plot_ratios(ADH1_peptides, ratio_string)
# Out:
# <img src="data:image/png;base64,..." width="960">

# %%
EKD_spectra = ps.get_by_peptide(id_result, 'EKDIVGAVLK') #this now selects just spectra with this peptide sequence

# %%
EKD_plots = ps.plot_ratios(EKD_spectra, ratio_string)
# Out:
# <img src="data:image/png;base64,..." width="192">

# %% [markdown]
# ### Plot individual sepctra
# * Finally, we will plot individual spectra to look at the quality of the fits

# %%
#this function retrieves an individual fit spectra
ps.read_spectra?

# %%
spectra = ps.read_spectra(id_result.iloc[10], ft, working_path=wd) #gets a single spectra defined by a single row

# %%
#this function plots a single fit given a spectra
ps.plot_fit?

# %%
f, axes = plt.subplots(nrows=2, ncols=1, gridspec_kw={'height_ratios': [5, 1]}, figsize=[8,5], sharex=True)
ps.plot_fit(spectra, axes[0], axes[1])
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="576">

# %%
#this is a warpper function to do the above operations in one call
ps.plot_single_spectra?

# %%
ax = ps.plot_single_spectra(id_result.iloc[10], ft, working_path=wd, fig_size=[8,5])
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="576">

# %% [markdown]
# ### Plot all spectra for a peptide
# * Here, we will plot all of the spectra for a given peptide

# %%
peptide_of_interest = filt_id.loc[0,'pep']

# %%
relevant_spectra = ps.get_by_peptide(id_result, peptide_of_interest)

# %%
#this command will plot a group of related spectra
ps.plot_spectra_group?

# %%
ps.plot_spectra_group(relevant_spectra, ft, working_path=wd, page_size=(12,24), fig_layout=(2,6))
# Out:
# plotting page 0 of 1...
# <img src="data:image/png;base64,..." width="864">
# plotting page 1 of 1...
# <img src="data:image/png;base64,..." width="864">

# %% [markdown]
# ### Plot all spectra for a protein
# * Finally, we can plot all spectra for a given protein

# %%
relevant_spectra = ps.get_by_protein(filt_id, all_proteins[1])

# %%
ps.plot_spectra_group(relevant_spectra, ft, working_path=wd, page_size=(12,24), fig_layout=(2,6))
# Out:
# plotting page 0 of 2...
# <img src="data:image/png;base64,..." width="864">
# plotting page 1 of 2...
# <img src="data:image/png;base64,..." width="864">
# plotting page 2 of 2...
# <img src="data:image/png;base64,..." width="864">
